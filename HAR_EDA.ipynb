# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = features

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\2747640118.py:6: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\2747640118.py:8: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2255           0.281947          -0.014485          -0.135395
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2255         -0.986253          -0.96551          -0.94042         -0.989466
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2255         -0.965145         -0.938543         -0.903157  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2255                     0.001864                             -0.037361
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2255                         -0.286228                              0.447434
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2255             -0.908429              0.097745             -0.049977
#
#       subject  Activity  ActivityName
# 2255       14         4       SITTING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = features

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\1245893344.py:6: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\1245893344.py:9: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2757           0.282454           -0.01932          -0.050366
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2757         -0.989249         -0.869059         -0.912595         -0.991593
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2757         -0.879859         -0.915488         -0.918914  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2757                     0.005263                              0.169161
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2757                         -0.738907                              0.460529
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2757             -0.842737               0.19873              0.060834
#
#       subject  Activity  ActivityName
# 2757       24         5      STANDING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.histplot(train.Activity)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\71913079.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[()]','')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\71913079.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[-]', '')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\71913079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   columns = columns.str.replace('[,]','')
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName',aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
# C:\Users\HP\AppData\Local\Temp\ipykernel_13660\246852771.py:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.033s...
# [t-SNE] Computed neighbors for 7352 samples in 3.462s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597464
# [t-SNE] Computed conditional probabilities in 0.039s
# [t-SNE] Iteration 50: error = 119.3534622, gradient norm = 0.0418662 (50 iterations in 5.287s)
# [t-SNE] Iteration 100: error = 105.0473557, gradient norm = 0.0229906 (50 iterations in 2.870s)
# [t-SNE] Iteration 150: error = 99.7925873, gradient norm = 0.0204441 (50 iterations in 2.816s)
# [t-SNE] Iteration 200: error = 96.7613525, gradient norm = 0.0133332 (50 iterations in 2.652s)
# [t-SNE] Iteration 250: error = 94.6629791, gradient norm = 0.0118856 (50 iterations in 2.573s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.662979
# [t-SNE] Iteration 300: error = 4.2691584, gradient norm = 0.0181426 (50 iterations in 2.608s)
# [t-SNE] Iteration 350: error = 3.3595445, gradient norm = 0.0191698 (50 iterations in 2.554s)
# [t-SNE] Iteration 400: error = 2.8626990, gradient norm = 0.0153991 (50 iterations in 2.884s)
# [t-SNE] Iteration 450: error = 2.5694699, gradient norm = 0.0133949 (50 iterations in 2.625s)
# [t-SNE] Iteration 500: error = 2.3689365, gradient norm = 0.0113261 (50 iterations in 2.448s)
# [t-SNE] Iteration 550: error = 2.2201185, gradient norm = 0.0101941 (50 iterations in 2.242s)
# [t-SNE] Iteration 600: error = 2.1039610, gradient norm = 0.0092523 (50 iterations in 2.234s)
# [t-SNE] Iteration 650: error = 2.0091121, gradient norm = 0.0083427 (50 iterations in 2.235s)
# [t-SNE] Iteration 700: error = 1.9297630, gradient norm = 0.0078582 (50 iterations in 2.403s)
# [t-SNE] Iteration 750: error = 1.8619198, gradient norm = 0.0074408 (50 iterations in 2.289s)
# [t-SNE] Iteration 800: error = 1.8029672, gradient norm = 0.0070586 (50 iterations in 2.267s)
# [t-SNE] Iteration 850: error = 1.7511818, gradient norm = 0.0066812 (50 iterations in 2.195s)
# [t-SNE] Iteration 900: error = 1.7050462, gradient norm = 0.0063008 (50 iterations in 2.227s)
# [t-SNE] Iteration 950: error = 1.6635578, gradient norm = 0.0061863 (50 iterations in 2.204s)
# [t-SNE] Iteration 1000: error = 1.6261408, gradient norm = 0.0058260 (50 iterations in 2.339s)
# [t-SNE] KL divergence after 1000 iterations: 1.626141
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.026s...
# [t-SNE] Computed neighbors for 7352 samples in 3.015s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.067s
# [t-SNE] Iteration 50: error = 107.1604004, gradient norm = 0.0392423 (50 iterations in 5.029s)
# [t-SNE] Iteration 100: error = 95.6708145, gradient norm = 0.0154121 (50 iterations in 3.244s)
# [t-SNE] Iteration 150: error = 92.3911667, gradient norm = 0.0089047 (50 iterations in 2.719s)
# [t-SNE] Iteration 200: error = 90.7201767, gradient norm = 0.0071771 (50 iterations in 2.725s)
# [t-SNE] Iteration 250: error = 89.6879196, gradient norm = 0.0052802 (50 iterations in 2.802s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.687920
# [t-SNE] Iteration 300: error = 3.7114756, gradient norm = 0.0166928 (50 iterations in 2.839s)
# [t-SNE] Iteration 350: error = 2.9566498, gradient norm = 0.0166418 (50 iterations in 2.654s)
# [t-SNE] Iteration 400: error = 2.5391340, gradient norm = 0.0158141 (50 iterations in 2.702s)
# [t-SNE] Iteration 450: error = 2.2877934, gradient norm = 0.0133557 (50 iterations in 2.741s)
# [t-SNE] Iteration 500: error = 2.1233659, gradient norm = 0.0117687 (50 iterations in 2.858s)
# [t-SNE] Iteration 550: error = 2.0057104, gradient norm = 0.0104374 (50 iterations in 2.219s)
# [t-SNE] Iteration 600: error = 1.9158984, gradient norm = 0.0095071 (50 iterations in 2.243s)
# [t-SNE] Iteration 650: error = 1.8446420, gradient norm = 0.0087594 (50 iterations in 2.235s)
# [t-SNE] Iteration 700: error = 1.7863324, gradient norm = 0.0080982 (50 iterations in 2.273s)
# [t-SNE] Iteration 750: error = 1.7376565, gradient norm = 0.0075274 (50 iterations in 2.315s)
# [t-SNE] Iteration 800: error = 1.6961687, gradient norm = 0.0070943 (50 iterations in 2.225s)
# [t-SNE] Iteration 850: error = 1.6602781, gradient norm = 0.0066705 (50 iterations in 2.217s)
# [t-SNE] Iteration 900: error = 1.6287427, gradient norm = 0.0063302 (50 iterations in 2.296s)
# [t-SNE] Iteration 950: error = 1.6008298, gradient norm = 0.0060148 (50 iterations in 2.227s)
# [t-SNE] Iteration 1000: error = 1.5762763, gradient norm = 0.0056982 (50 iterations in 2.352s)
# [t-SNE] KL divergence after 1000 iterations: 1.576276
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.033s...
# [t-SNE] Computed neighbors for 7352 samples in 2.971s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.127s
# [t-SNE] Iteration 50: error = 97.9022522, gradient norm = 0.0340022 (50 iterations in 4.758s)
# [t-SNE] Iteration 100: error = 88.9458237, gradient norm = 0.0097994 (50 iterations in 3.572s)
# [t-SNE] Iteration 150: error = 86.7474518, gradient norm = 0.0061161 (50 iterations in 3.300s)
# [t-SNE] Iteration 200: error = 85.7422562, gradient norm = 0.0044993 (50 iterations in 3.248s)
# [t-SNE] Iteration 250: error = 85.1433868, gradient norm = 0.0036143 (50 iterations in 3.231s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.143387
# [t-SNE] Iteration 300: error = 3.2545607, gradient norm = 0.0156653 (50 iterations in 3.205s)
# [t-SNE] Iteration 350: error = 2.6057813, gradient norm = 0.0150370 (50 iterations in 2.886s)
# [t-SNE] Iteration 400: error = 2.2685466, gradient norm = 0.0140113 (50 iterations in 2.942s)
# [t-SNE] Iteration 450: error = 2.0602050, gradient norm = 0.0129993 (50 iterations in 2.866s)
# [t-SNE] Iteration 500: error = 1.9229999, gradient norm = 0.0115893 (50 iterations in 2.487s)
# [t-SNE] Iteration 550: error = 1.8269802, gradient norm = 0.0103390 (50 iterations in 2.364s)
# [t-SNE] Iteration 600: error = 1.7558522, gradient norm = 0.0093849 (50 iterations in 2.372s)
# [t-SNE] Iteration 650: error = 1.7007711, gradient norm = 0.0084859 (50 iterations in 2.509s)
# [t-SNE] Iteration 700: error = 1.6566343, gradient norm = 0.0078871 (50 iterations in 2.370s)
# [t-SNE] Iteration 750: error = 1.6200192, gradient norm = 0.0074138 (50 iterations in 2.457s)
# [t-SNE] Iteration 800: error = 1.5897346, gradient norm = 0.0067738 (50 iterations in 2.382s)
# [t-SNE] Iteration 850: error = 1.5640535, gradient norm = 0.0063704 (50 iterations in 2.528s)
# [t-SNE] Iteration 900: error = 1.5422843, gradient norm = 0.0058059 (50 iterations in 2.370s)
# [t-SNE] Iteration 950: error = 1.5235860, gradient norm = 0.0055259 (50 iterations in 2.400s)
# [t-SNE] Iteration 1000: error = 1.5072235, gradient norm = 0.0051148 (50 iterations in 2.522s)
# [t-SNE] KL divergence after 1000 iterations: 1.507223
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.033s...
# [t-SNE] Computed neighbors for 7352 samples in 3.062s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.226s
# [t-SNE] Iteration 50: error = 89.2999573, gradient norm = 0.0292968 (50 iterations in 6.426s)
# [t-SNE] Iteration 100: error = 82.9606552, gradient norm = 0.0074143 (50 iterations in 3.977s)
# [t-SNE] Iteration 150: error = 81.5937500, gradient norm = 0.0044677 (50 iterations in 3.898s)
# [t-SNE] Iteration 200: error = 81.0272293, gradient norm = 0.0032163 (50 iterations in 3.977s)
# [t-SNE] Iteration 250: error = 80.7000427, gradient norm = 0.0026021 (50 iterations in 3.809s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.700043
# [t-SNE] Iteration 300: error = 2.8006022, gradient norm = 0.0146604 (50 iterations in 3.656s)
# [t-SNE] Iteration 350: error = 2.2539694, gradient norm = 0.0134174 (50 iterations in 3.215s)
# [t-SNE] Iteration 400: error = 1.9892688, gradient norm = 0.0122082 (50 iterations in 2.729s)
# [t-SNE] Iteration 450: error = 1.8312920, gradient norm = 0.0112877 (50 iterations in 2.722s)
# [t-SNE] Iteration 500: error = 1.7254978, gradient norm = 0.0105229 (50 iterations in 2.843s)
# [t-SNE] Iteration 550: error = 1.6504444, gradient norm = 0.0097239 (50 iterations in 2.955s)
# [t-SNE] Iteration 600: error = 1.5956225, gradient norm = 0.0088303 (50 iterations in 2.945s)
# [t-SNE] Iteration 650: error = 1.5543826, gradient norm = 0.0079989 (50 iterations in 2.915s)
# [t-SNE] Iteration 700: error = 1.5218695, gradient norm = 0.0073688 (50 iterations in 2.805s)
# [t-SNE] Iteration 750: error = 1.4959782, gradient norm = 0.0067019 (50 iterations in 3.297s)
# [t-SNE] Iteration 800: error = 1.4747127, gradient norm = 0.0062536 (50 iterations in 2.972s)
# [t-SNE] Iteration 850: error = 1.4575781, gradient norm = 0.0055032 (50 iterations in 2.721s)
# [t-SNE] Iteration 900: error = 1.4435970, gradient norm = 0.0050103 (50 iterations in 2.737s)
# [t-SNE] Iteration 950: error = 1.4315708, gradient norm = 0.0046075 (50 iterations in 2.980s)
# [t-SNE] Iteration 1000: error = 1.4220808, gradient norm = 0.0039049 (50 iterations in 3.431s)
# [t-SNE] KL divergence after 1000 iterations: 1.422081
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.037s...
# [t-SNE] Computed neighbors for 7352 samples in 3.692s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.672s
# [t-SNE] Iteration 50: error = 78.8754044, gradient norm = 0.0246655 (50 iterations in 9.522s)
# [t-SNE] Iteration 100: error = 75.2882233, gradient norm = 0.0051687 (50 iterations in 5.892s)
# [t-SNE] Iteration 150: error = 74.5521698, gradient norm = 0.0031378 (50 iterations in 4.607s)
# [t-SNE] Iteration 200: error = 74.2562790, gradient norm = 0.0023966 (50 iterations in 4.683s)
# [t-SNE] Iteration 250: error = 74.0930023, gradient norm = 0.0018788 (50 iterations in 4.371s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.093002
# [t-SNE] Iteration 300: error = 2.2387969, gradient norm = 0.0130158 (50 iterations in 3.967s)
# [t-SNE] Iteration 350: error = 1.8229260, gradient norm = 0.0112955 (50 iterations in 4.052s)
# [t-SNE] Iteration 400: error = 1.6400198, gradient norm = 0.0098735 (50 iterations in 3.599s)
# [t-SNE] Iteration 450: error = 1.5366105, gradient norm = 0.0088880 (50 iterations in 3.507s)
# [t-SNE] Iteration 500: error = 1.4704454, gradient norm = 0.0081786 (50 iterations in 3.610s)
# [t-SNE] Iteration 550: error = 1.4243529, gradient norm = 0.0075632 (50 iterations in 4.279s)
# [t-SNE] Iteration 600: error = 1.3904712, gradient norm = 0.0071661 (50 iterations in 4.357s)
# [t-SNE] Iteration 650: error = 1.3647331, gradient norm = 0.0065481 (50 iterations in 4.563s)
# [t-SNE] Iteration 700: error = 1.3451285, gradient norm = 0.0059149 (50 iterations in 4.363s)
# [t-SNE] Iteration 750: error = 1.3303695, gradient norm = 0.0052547 (50 iterations in 4.512s)
# [t-SNE] Iteration 800: error = 1.3195360, gradient norm = 0.0043670 (50 iterations in 4.473s)
# [t-SNE] Iteration 850: error = 1.3112770, gradient norm = 0.0037309 (50 iterations in 3.716s)
# [t-SNE] Iteration 900: error = 1.3048557, gradient norm = 0.0032669 (50 iterations in 3.503s)
# [t-SNE] Iteration 950: error = 1.2996157, gradient norm = 0.0029938 (50 iterations in 3.634s)
# [t-SNE] Iteration 1000: error = 1.2950473, gradient norm = 0.0026812 (50 iterations in 3.667s)
# [t-SNE] KL divergence after 1000 iterations: 1.295047
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
